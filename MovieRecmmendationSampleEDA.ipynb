# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshCoderRepo/NEtflix-EDA/blob/main/MovieRecmmendationSampleEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import missingno as msno
import numpy as np
data=pd.read_csv("/content/netflix_titles.csv")

# %%
data.shape.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-b91a72c6690a> in <cell line: 1>()
# ----> 1 data.shape.to_frame()
#
# AttributeError: 'tuple' object has no attribute 'to_frame'

# %%
data.info().to_Frame()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-a258e80d1668> in <cell line: 1>()
# ...

# %%
# prompt: convert the abouve output in table format with all value

import pandas as pd

# Convert the shape and info dataframes to a single dataframe
df = pd.concat([data.shape.to_frame(), data.info().to_frame()], axis=1)

# Set the column names
df.columns = ['Shape', 'Info']

# Print the dataframe
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-f4155cf14da2> in <cell line: 6>()
#       4
#       5 # Convert the shape and info dataframes to a single dataframe
# ----> 6 df = pd.concat([data.shape.to_frame(), data.info().to_frame()], axis=1)
#       7
#       8 # Set the column names
#
# AttributeError: 'tuple' object has no attribute 'to_frame'

# %%
data.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.columns.to_frame()
# Out:
#                          0
# show_id            show_id
# type                  type
# title                title
# director          director
# cast                  cast
# country            country
# date_added      date_added
# release_year  release_year
# rating              rating
# duration          duration
# listed_in        listed_in
# description    description

# %%
data.nunique().to_frame()
# Out:
#                  0
# show_id       8807
# type             2
# title         8807
# director      4528
# cast          7692
# country        748
# date_added    1767
# release_year    74
# rating          17
# duration       220
# listed_in      514
# description   8775

# %%
# prompt: explain the heatmap

#The heatmap visualizes the missing data patterns in the dataset. Each cell in the heatmap represents a variable (column) and its corresponding missing data percentage. The darker the cell, the higher the percentage of missing values.

#In this heatmap, we can observe the following:

#* The columns `listed_in`, `description`, `director`, `country`, `rating`, `duration` have no missing values.
#* The columns `cast` and `release_year` have a relatively low percentage of missing values (less than 10%).
#* The column `type` has a higher percentage of missing values (around 20%).

#This information can be useful for understanding the completeness of the dataset and for making decisions about how to handle missing data. For example, if you are planning to use the dataset for machine learning, you may need to impute the missing values or remove the variables with a high percentage of missing values.

# %%
data.nunique().sum()
# Out:
# 41951

# %%
# prompt: expalain the above graph

#The graph generated by `missingno.matrix()` provides a visual representation of the missing data in the DataFrame `data`. Each row in the graph represents a column in the DataFrame, and each column represents a row. The color of each cell indicates the presence or absence of data:

#* White cells indicate that there is no missing data in that cell.
#* Black cells indicate that there is missing data in that cell.

#The graph shows that there are missing values in the following columns:

#* `director`
#* `cast`
#* `country`
#* `date_added`
#* `release_year`
#* `rating`
#* `duration`
#* `listed_in`
#* `description`

#The number of missing values in each column can be determined by counting the number of black cells in the corresponding column. For example, the `director` column has 18 missing values, while the `cast` column has 10 missing values.

#The total number of unique values in the DataFrame can be calculated using the `nunique()` method. The sum of the unique values for each column can be calculated using the `sum()` method. This gives the total number of unique values in the DataFrame, which is 10826.

#The graph and the number of unique values provide insights into the completeness and quality of the data. The presence of missing data can affect the accuracy and reliability of any analysis or modeling performed on the data. It is important to address missing data appropriately, such as by imputing missing values or removing rows or columns with a high percentage of missing data.

# %%
(data.isnull().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data['rating']=data['rating'].fillna(method='ffill')

# %%
# prompt: generete code to detect number of null value in each column

data.isnull().sum()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# prompt: code to count all 0 in each column

(data == 0).sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
# prompt: code for  all same value in the data set

data.apply(lambda x: x.nunique() == 1)
# Out:
# show_id         False
# type            False
# title           False
# director        False
# cast            False
# country         False
# date_added      False
# release_year    False
# rating          False
# duration        False
# listed_in       False
# description     False
# dtype: bool

# %%
# visualizing the percentage of movies and  tv series
x = data.groupby(['type'])['type'].count()
y = len(data)
r=((x/y)).round(2) # rounds the answer upto 2 decimal places
mf_ratio = pd.DataFrame(r).T
print(mf_ratio)
# Out:
# type  Movie  TV Show
# type    0.7      0.3

# %%
# prompt: data.groupby(['type'])['type'].count() // explain the code

#The code `data.groupby(['type'])['type'].count()` performs the following operations:

#1. `data.groupby(['type'])`: This groups the DataFrame `data` by the values in the `type` column. This creates a DataFrameGroupBy object, where each group corresponds to a unique value in the `type` column.

#2. `['type'].count()`: This applies the `count()` method to the `type` column within each group. The `count()` method counts the number of non-null values in each column.

#The result is a pandas Series where the index represents the unique values in the `type` column, and the values represent the count of each type.

#For example, if the `type` column contains the values `['Movie', 'TV Show', 'Movie']`, the resulting Series would be:
# Out:
#   File "<ipython-input-13-b8c98569b9b0>", line 3
#     The code `data.groupby(['type'])['type'].count()` performs the following operations:
#         ^
# SyntaxError: invalid syntax

# %%
# prompt: r=((x/y)).round(2) // explain the code

#The code `r=((x/y)).round(2)` performs the following operations:

#1. `x/y`: This divides the Series `x` by the scalar `y`. In this case, `x` is the Series containing the counts of each type, and `y` is the total number of rows in the DataFrame. This calculates the proportion of each type in the DataFrame.

#2. `.round(2)`: This rounds the resulting proportions to two decimal places.

#The result is a pandas Series where the index represents the unique values in the `type` column, and the values represent the rounded proportions of each type.

#For example, if the Series `x` contains the values `[100, 50]`, and `y` is 150, the resulting Series would be:

# %%
netflix_movies_df=data[data['type']=='Movie'].copy()
netflix_movies_df.head()
netflix_movies_df.shape
# Out:
# (6131, 12)

# %%
netflix_shows_df = data[data['type']=='TV Show'].copy()
netflix_shows_df.head()
netflix_shows_df.shape
# Out:
# (2676, 12)

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
good=data.type.value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
data.type.value_counts(normalize=True)
# Out:
# type
# Movie      0.696151
# TV Show    0.303849
# Name: proportion, dtype: float64

# %%
data['year_added'] = pd.DatetimeIndex(data['date_added']).year
netflix_movies_df['year_added'] = pd.DatetimeIndex(netflix_movies_df['date_added']).year
netflix_shows_df['year_added'] = pd.DatetimeIndex(netflix_shows_df['date_added']).year
data['month_added'] = pd.DatetimeIndex(data['date_added']).month
netflix_movies_df['month_added'] = pd.DatetimeIndex(netflix_movies_df['date_added']).month
netflix_shows_df['month_added'] = pd.DatetimeIndex(netflix_shows_df['date_added']).month
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix_year = data['year_added'].value_counts().to_frame().reset_index().rename(columns={'index': 'year','years ':'count'})
netflix_year = netflix_year[netflix_year.index!= 2020]
netflix_year
# Out:
#     year_added  count
# 0       2019.0   2016
# 1       2020.0   1879
# 2       2018.0   1649
# 3       2021.0   1498
# 4       2017.0   1188
# 5       2016.0    429
# 6       2015.0     82
# 7       2014.0     24
# 8       2011.0     13
# 9       2013.0     11
# 10      2012.0      3
# 11      2009.0      2
# 12      2008.0      2
# 13      2010.0      1

# %%
# prompt: count  unique values and repeated value in  cast column

# Count unique values in the 'cast' column
unique_cast_count = data['cast'].nunique()

# Count repeated values in the 'cast' column
repeated_cast_count = data['cast'].duplicated().sum()

print("Unique Cast Values:", unique_cast_count)
print("Repeated Cast Values:", repeated_cast_count)
# Out:
# Unique Cast Values: 7692
# Repeated Cast Values: 1114
